# %% [markdown]
# #  1. CIR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import sys
sys.path.append("./models")

from cir.simulation import DataSimulation
from cir.backtest import ModelBacktester

# %%
def read_and_combine_files(file_patterns, asset_name):
    """Читает и объединяет CSV файлы для одного актива"""
    dfs = []
    for file in file_patterns:
        df = pd.read_csv(file, sep=';', skiprows=1, names=['TICKER','PER','DATE','TIME','OPEN','HIGH','LOW','CLOSE','VOL'])
        df['DATE'] = pd.to_datetime(df['DATE'], format='%y%m%d')
        dfs.append(df)
    combined = pd.concat(dfs)[['DATE', 'CLOSE']]
    combined.columns = ['DATE', asset_name]
    return combined

assets = {
    'vxx': ["data/VXX_160101_201231.csv", "data/VXX_210101_250616.csv"],
    'treasures': ["data/SHY_160101_201231.csv", "data/SHY_210101_250616.csv"],
    'snp': ["data/SPX_160101_201231.csv", "data/SPX_210101_250616.csv"]
}

asset_dfs = {}
for name, files in assets.items():
    asset_dfs[name] = read_and_combine_files(files, name)
merged = asset_dfs['vxx']
for name in ['treasures', 'snp']:
    merged = merged.merge(asset_dfs[name], on='DATE', how='inner')
merged = merged.set_index('DATE').sort_index()

vxx = merged['vxx'].values
treasures = merged['treasures'].values
snp = merged['snp'].values

# %%
np.random.seed(819946)

n = 800
vxx = merged['vxx'].values[n:]
treasures = merged['treasures'].values[n:]
snp = merged['snp'].values[n:]
 
simulator = DataSimulation(
        vix_array=vxx, 
        treasures_array=treasures, 
        snp_array=snp,
        vix_method='log_likelihood_article',
        treasures_method='ols',
        forecast_days=63,  # Прогноз на 60 дней
        num_simulations=15  # 15 симуляций
    )
    
vix_sim, treas_sim, snp_sim = simulator.get_processes()
simulator.plot_simulations(vix_sim, treas_sim, snp_sim)
# Out:
# Методы оценки параметров: VIX: log_likelihood_article, Treasuries: ols
# Прогноз на 63 дней, 15 симуляций

# %%
def plot_line(array, name):
    plt.figure(figsize=(14, 5)) 
    plt.plot(range(1, len(array) + 1), array, marker='o')
    plt.title(name)
    plt.xlabel('День')
    plt.ylabel('Значение')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
sim_snp_track = snp_sim.mean(axis=1)
plot_line(sim_snp_track, 'Усредненная траектория S&P500')

# %%
np.random.seed(42)

n = 1150
# Создание и запуск бэктестера
backtester = ModelBacktester(
        vix_data=merged['vxx'][n :],
        treas_data=merged['treasures'][n :],
        snp_data=merged['snp'][n :],
        train_window=126,    # 1 год обучения
        test_periods=4,      
        forecast_days=30,    # Прогноз на 30 дней
        vix_method='log_likelihood_article',
        treasures_method='ols'
)
    
backtester.run_backtest()
    
backtester.plot_backtest_results(all_periods=True)
backtester.plot_error_distribution()
metrics_df = backtester.plot_metrics_comparison()
        
# Вывод метрик
backtester.print_summary_report()
        
# Дополнительный анализ
print("\nДополнительный анализ:")
print(f"Средняя абсолютная ошибка (MAE): {backtester.metrics['MAE']:.2f} пунктов S&P 500")
print(f"Средняя процентная ошибка (MAPE): {backtester.metrics['MAPE']:.2f}%")
print(f"Корреляция прогноза с реальностью: {backtester.metrics['Correlation']:.4f}")
        
print("\nМетрики по периодам:")
print(metrics_df)
# Out:
# Запуск бэктеста на 4 периодов...
# Обучающее окно: 126 дней, Прогноз: 30 дней
# Период 1/4 завершен: обучение до 2023-06-20, прогноз на 30 дней
# Период 2/4 завершен: обучение до 2024-02-01, прогноз на 30 дней
# Период 3/4 завершен: обучение до 2024-09-16, прогноз на 30 дней
# Период 4/4 завершен: обучение до 2025-05-01, прогноз на 30 дней
#
# Бэктест завершен!
#
# Метрики качества прогноза:
# MAE: 159.1675
# RMSE: 225.4567
# MAPE: 3.0432
# R2: 0.8458
# Correlation: 0.9481
# Построение графиков для всех 4 периодов...
# ======================================================================
# СВОДНЫЙ ОТЧЕТ ПО БЭКТЕСТУ МОДЕЛИ ПРОГНОЗИРОВАНИЯ
# ======================================================================
#
# Конфигурация модели:
# - Метод оценки VIX: log_likelihood_article
# - Метод оценки Treasuries: ols
# - Окно обучения: 126 дней
# - Прогнозный горизонт: 30 дней
# - Количество тестовых периодов: 4
#
# Период данных:
# - Начало: 2022-09-02
# - Конец: 2025-06-13
# - Всего дней: 697
#
# Результаты бэктестинга:
# - Общее количество прогнозов: 120
# - Период первого прогноза: 2023-06-21 - 2023-08-02
# - Период последнего прогноза: 2025-05-02 - 2025-06-13
#
# Метрики качества прогноза:
# - MAE: 159.1675
# - RMSE: 225.4567
# - MAPE: 3.0432
# - R2: 0.8458
# - Correlation: 0.9481
#
# ======================================================================
#
# Дополнительный анализ:
# Средняя абсолютная ошибка (MAE): 159.17 пунктов S&P 500
# Средняя процентная ошибка (MAPE): 3.04%
# Корреляция прогноза с реальностью: 0.9481
#
# Метрики по периодам:
#    Period Start Date   End Date         MAE        RMSE      MAPE
# 0       1 2023-06-21 2023-08-02  124.408229  159.558737  2.757642
# 1       2 2024-02-02 2024-03-15  255.526411  353.448336  4.998435
# 2       3 2024-09-17 2024-10-28  178.047557  209.361613  3.082666
# 3       4 2025-05-02 2025-06-13   78.687800   95.424697  1.334084

# %% [markdown]
# # WGAN NOISE

# %%
from models.noise_gan import wgan_gp_residuals

# %%
# Загрузка данных
file_list = ["data/SPX_160101_201231.csv", "data/SPX_210101_250616.csv"]
combined_df = read_and_combine_files(file_list, "SPX")
prices = combined_df["SPX"].values

# %%
prices
# Out:
# array([2012.66, 2016.71, 1990.26, ..., 6022.24, 6045.26, 5976.97])

# %%
# Обучение модели или загрузка существующей
G, C = wgan_gp_residuals.train_wgan_gp(
    prices,
    num_epochs=2000,
    print_every=200,
    seq_len=30,
)
# Out:
# Working directory: C:\Users\rawen\MyProjects\hse\1 курс\coursepaper\m
# Saving to: .
# Metrics path: .\metrics_log.csv
# Generator path: .\generator.pth
# Found metrics_log.csv. Training skipped.

# %%
# Визуализация метрик
wgan_gp_residuals.plot_saved_metrics("metrics_log.csv")

# %%
_, modified = wgan_gp_residuals.apply_noise_to_prices(
    prices=sim_snp_track,
    noise_dim=20,
    seq_len=30,
)

# %%
# Out:
# array([5939.28746035, 6275.72073489, 6433.03180507, 6479.95778482,
#        6450.44282036, 6379.53807583, 6293.22624619, 6207.76295588,
#        6131.83437482, 6069.05524276, 6019.98613216, 5983.55594303,
#        5957.97609814, 5941.29490317, 5931.69588867, 5927.64342262,
#        6846.19821196, 6872.77876377, 6898.83329361, 6928.71702467,
#        6963.55302716, 7002.88661303, 7045.63301494, 7090.5990039 ,
#        7136.73611812, 7183.2380955 , 7229.55668994, 7275.36986592,
#        7320.53841624, 7365.06148246, 7409.03442044, 7452.61631083,
#        7496.00590873, 7539.42115081, 7583.08784457, 7627.23072807,
#        7672.06701099, 7717.80066679, 7764.62117336, 7812.6985407 ,
#        7862.18655465, 7913.21770708])

# %%
original
# Out:
# array([5939.28746035, 6058.13216987, 6022.08974953])

# %%
np.append(gbm_prices, [6100])
# Out:
# array([5976.97      , 6049.32091829, 6095.80944013, 6150.11586743,
#        6151.47909032, 6163.36233611, 6211.44734776, 6252.04495338,
#        6241.2400183 , 6246.27229434, 6288.78838458, 6242.88550697,
#        6277.29285285, 6276.71905257, 6265.76480125, 6192.92736381,
#        6130.26860989, 6123.7365003 , 6125.5026228 , 6138.12718462,
#        6125.08786794, 6051.16416529, 6106.03487677, 6080.16347816,
#        6059.70547028, 6090.96629165, 6023.61932462, 6124.58015736,
#        6152.57404134, 6189.96722304, 6277.9913262 , 6275.82087536,
#        6307.08736641, 6311.88013938, 6283.35043789, 6356.74252202,
#        6390.64705159, 6368.04335814, 6303.78939457, 6311.70837971,
#        6217.1590139 , 6152.57161607, 6145.31282339, 6186.90643525,
#        6203.95544076, 6192.5365875 , 6184.53769637, 6072.60150056,
#        6002.84080795, 6006.79800086, 5988.33019799, 6010.02114728,
#        6011.99899365, 6021.18548982, 5968.90349958, 5945.94835501,
#        5992.25070157, 5986.79673727, 5974.70522373, 6027.22970601,
#        5939.28746035, 6058.13216987, 6022.08974953, 6100.        ])

# %%
gbm_prices = sim_snp_track

# 2. Применение GAN-шума с визуализацией
noisy_prices = wgan_gp_residuals.apply_gan_noise_to_gbm_trajectory(
    gbm_prices=sim_snp_track[:100],
    noise_dim=20,
    seq_len=62,
    window=30,  # более гладкий результат
)


# 3. Дополнительный анализ (опционально)
print("Original GBM final price:", gbm_prices[-1])
print("Noisy GBM final price:", noisy_prices[-1])
print("Difference:", noisy_prices[-1] - gbm_prices[-1])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 4
#       1 gbm_prices = sim_snp_track
#       3 # 2. Применение GAN-шума с визуализацией
# ----> 4 noisy_prices = wgan_gp_residuals.apply_gan_noise_to_gbm_trajectory(
#       5     gbm_prices=sim_snp_track[:100],
#       6     noise_dim=20,
#       7     seq_len=62,
#       8     window=30,  # более гладкий результат
#       9 )
#      12 # 3. Дополнительный анализ (опционально)
#      13 print("Original GBM final price:", gbm_prices[-1])
#
# File ~\MyProjects\hse\1 курс\coursepaper\m\models\noise_gan\wgan_gp_residuals.py:281, in apply_gan_noise_to_gbm_trajectory(gbm_prices, noise_dim, seq_len, window, model_path, plot)
#     278 else:
#     279     raise FileNotFoundError(f"Generator model not found at {model_path}")
# --> 281 assert len(gbm_prices) >= seq_len + window, "GBM траектория слишком короткая"
#     283 # 1. Лог-доходности GBM
#     284 log_returns = np.log(gbm_prices[1:] / gbm_prices[:-1])
#
# AssertionError: GBM траектория слишком короткая

# %%
plot_line(sim_snp_track, 'Усредненная траектория S&P500')
